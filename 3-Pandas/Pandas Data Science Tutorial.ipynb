# %% [markdown]
# ## Loading data into Pandas

# %%
import pandas as pd
import numpy as np

# df = pd.read_csv('pokemon_data.csv')

# df.head(5)
# df_xlsx = pd.read_excel('pokemon_data.xlsx')
# df_xlsx.head(3)

df = pd.read_csv('pokemon_data.txt', delimiter='\t')

df.head(5)

# df['HP']
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False
#
# [5 rows x 12 columns]

# %%
# Load from a dictionary
d_dic ={'Name':['Bulbasaur','Ivysaur'],
        'Type 1':['Grass',np.nan]} 


df_dic = pd.DataFrame(data = d_dic)
df_dic
# df_dic.info()

df_dic.dropna(axis=0,inplace=True)
df_dic
# Out:
#         Name Type 1
# 0  Bulbasaur  Grass
#
# [1 rows x 2 columns]

# %%
np_data = np.zeros(3)
np_df = pd.DataFrame(data=np_data.reshape(1,3), columns=['c1','c2','c3'])
np_df
# Out:
#     c1   c2   c3
# 0  0.0  0.0  0.0
#
# [1 rows x 3 columns]

# %% [markdown]
# ## Reading Data in Pandas

# %%
#### Read Headers
# list(df.columns)

## Read each Column
df2=df[['Name', 'Type 1', 'HP']]
df2
## Read Each Row
# df2.iloc[20:24]
# df.iloc[0:4]

for index, row in df.iterrows():
    print(row['Name'])
    print(row['Attack'])
    print('***')

# df.loc[df['Type 1'] == "Grass"]

## Read a specific location (R,C)
# df.iloc[2,1]
# Out:
# Bulbasaur
# 49
# ***
# Ivysaur
# 62
# ***
# Venusaur
# 82
# ***
# VenusaurMega Venusaur
# 100
# ***
# Charmander
# 52
# ***
# Charmeleon
# 64
# ***
# Charizard
# 84
# ***
# CharizardMega Charizard X
# 130
# ***
# CharizardMega Charizard Y
# 104
# ***
# Squirtle
# 48
# ***
# Wartortle
# 63
# ***
# Blastoise
# 83
# ***
# BlastoiseMega Blastoise
# 103
# ***
# Caterpie
# 30
# ***
# Metapod
# 20
# ***
# Butterfree
# 45
# ***
# Weedle
# 35
# ***
# Kakuna
# 25
# ***
# Beedrill
# 90
# ***
# BeedrillMega Beedrill
# 150
# ***
# Pidgey
# 45
# ***
# Pidgeotto
# 60
# ***
# Pidgeot
# 80
# ***
# PidgeotMega Pidgeot
# 80
# ***
# Rattata
# 56
# ***
# Raticate
# 81
# ***
# Spearow
# 60
# ***
# Fearow
# 90
# ***
# Ekans
# 60
# ***
# Arbok
# 85
# ***
# Pikachu
# 55
# ***
# Raichu
# 90
# ***
# Sandshrew
# 75
# ***
# Sandslash
# 100
# ***
# Nidoran (Female)
# 47
# ***
# Nidorina
# 62
# ***
# Nidoqueen
# 92
# ***
# Nidoran (Male)
# 57
# ***
# Nidorino
# 72
# ***
# Nidoking
# 102
# ***
# Clefairy
# 45
# ...

# %% [markdown]
# ## Sorting/Describing Data

# %%
df.describe()
# Out:
#             #      HP  Attack  Defense  Sp. Atk  Sp. Def   Speed  Generation
# count  800.00  800.00  800.00   800.00   800.00   800.00  800.00      800.00
# mean   362.81   69.26   79.00    73.84    72.82    71.90   68.28        3.32
# std    208.34   25.53   32.46    31.18    32.72    27.83   29.06        1.66
# min      1.00    1.00    5.00     5.00    10.00    20.00    5.00        1.00
# 25%    184.75   50.00   55.00    50.00    49.75    50.00   45.00        2.00
# 50%    364.50   65.00   75.00    70.00    65.00    70.00   65.00        3.00
# 75%    539.25   80.00  100.00    90.00    95.00    90.00   90.00        5.00
# max    721.00  255.00  190.00   230.00   194.00   230.00  180.00        6.00
#
# [8 rows x 8 columns]

# %%
# sorted_df = df.sort_values('Name', ascending=False)

sorted_df = df.sort_values(['Name','Type 1','HP'], ascending=[1,1,0])#,inplace=True)

# sorted_df = df.sort_values([1,2,3],axis=1)#,inplace=True)
sorted_df
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 510  460                Abomasnow    Grass     Ice   90      92       75
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 68    63                     Abra  Psychic     NaN   25      20       15
# 392  359                    Absol     Dark     NaN   65     130       60
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 632  571                  Zoroark     Dark     NaN   60     105       60
# 631  570                    Zorua     Dark     NaN   40      65       40
# 46    41                    Zubat   Poison  Flying   40      45       35
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# ## Making changes to the data

# %%
# %%timeit
# df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']
# df.head()
# type(df['Name'])
# df = df.drop(columns=['Total'])
# df.head()
df['Total'] = df.iloc[:, 4:10].sum(axis=1)


# list(df.columns.values)
# # [1,2]+[3]
# cols = list(df.columns)
# df = df[cols[0:4] + [cols[-1]]+cols[4:12]]

# df.head(5)

# %%
s= pd.Series([100,101,102])
# s.to_numpy()
d= s.to_frame(name='Col1')
d['Col1']
# Out:
# 0    100
# 1    101
# 2    102
# Name: Col1, Length: 3, dtype: int64

# %%
45+49+49+65+65+45
# Out:
# 318

# %% [markdown]
# ## Saving our Data (Exporting into Desired Format)

# %%
df2
# Out:
#                       Name   Type 1  HP
# 0                Bulbasaur    Grass  45
# 1                  Ivysaur    Grass  60
# 2                 Venusaur    Grass  80
# 3    VenusaurMega Venusaur    Grass  80
# 4               Charmander     Fire  39
# ..                     ...      ...  ..
# 795                Diancie     Rock  50
# 796    DiancieMega Diancie     Rock  50
# 797    HoopaHoopa Confined  Psychic  80
# 798     HoopaHoopa Unbound  Psychic  80
# 799              Volcanion     Fire  80
#
# [800 rows x 3 columns]

# %%
# df2.to_csv('modified.csv', index=False)

#df.to_excel('modified.xlsx', index=False)

df2.to_csv('modified.txt', index=False, sep='\t')

# %% [markdown]
# ## Filtering Data

# %%
# df['Type 1'] == 'Grass'

# df[df['Type 1'] == 'Grass']

# mask = (df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['HP'] > 70)
# mask
# new_df = df[mask]

# # new_df = new_df.reset_index()
# new_df.reset_index(drop=True, inplace=True)

# list(new_df.index)

# new_df.to_csv('filtered.csv')

new_df = df[df['Name'].str.contains('Mega ')]
new_df
# Out:
#        #                       Name    Type 1    Type 2   HP  Attack  Defense  \
# 3      3      VenusaurMega Venusaur     Grass    Poison   80     100      123
# 7      6  CharizardMega Charizard X      Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y      Fire    Flying   78     104       78
# 12     9    BlastoiseMega Blastoise     Water       NaN   79     103      120
# 19    15      BeedrillMega Beedrill       Bug    Poison   65     150       40
# ..   ...                        ...       ...       ...  ...     ...      ...
# 498  448        LucarioMega Lucario  Fighting     Steel   70     145       88
# 511  460    AbomasnowMega Abomasnow     Grass       Ice   90     132      105
# 527  475        GalladeMega Gallade   Psychic  Fighting   68     165       95
# 591  531          AudinoMega Audino    Normal     Fairy  103      60      126
# 796  719        DiancieMega Diancie      Rock     Fairy   50     160      110
#
# ...

# %%
import re

# new_df = df[df['Name'].str.contains('^Pi\w*' , regex=True)]
new_df
# Out:
#        #                 Name    Type 1    Type 2   HP  Attack  Defense  \
# 20    16               Pidgey    Normal    Flying   40      45       40
# 21    17            Pidgeotto    Normal    Flying   63      60       55
# 22    18              Pidgeot    Normal    Flying   83      80       75
# 23    18  PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 30    25              Pikachu  Electric       NaN   35      55       40
# 136  127               Pinsir       Bug       NaN   65     125      100
# 137  127    PinsirMega Pinsir       Bug    Flying   65     155      120
# 186  172                Pichu  Electric       NaN   20      40       15
# 219  204               Pineco       Bug       NaN   50      65       90
# 239  221            Piloswine       Ice    Ground  100     100       80
# 438  393               Piplup     Water       NaN   53      51       53
# 558  499              Pignite      Fire  Fighting   90      93       55
# ...

# %%
# new_df.count()
new_df[new_df['Type 2'].isnull()]
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48 entries, 3 to 796
# Data columns (total 13 columns):
# #             48 non-null int64
# Name          48 non-null object
# Type 1        48 non-null object
# Type 2        39 non-null object
# HP            48 non-null int64
# Attack        48 non-null int64
# Defense       48 non-null int64
# Sp. Atk       48 non-null int64
# Sp. Def       48 non-null int64
# Speed         48 non-null int64
# Generation    48 non-null int64
# Legendary     48 non-null bool
# Total         48 non-null int64
# dtypes: bool(1), int64(9), object(3)
# memory usage: 4.9+ KB

# %% [markdown]
# ## Conditional Changes

# %%
# new_df.loc[new_df['Total'] > 500, 'Type 1'] = 'Flamer'
# new_df

# new_df.loc[new_df['Total'] > 500, 'Legendary'] = True
# new_df

# new_df.loc[df['Total'] >= 500, ['Generation','Legendary']] = [100, True]
# new_df

new_df.loc[new_df['Type 2'].isnull(), 'Type 2'] = 'Basic'
df

df = pd.read_csv('pokemon_data.csv')
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Type 2'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-128-69add89d6cbf> in <module>
#       8 # new_df
#       9
# ...

# %% [markdown]
# ## Set index

# %%
# newdf = df.set_index('Name', drop=True)
# newdf = df.set_index('Name' , drop=False )
# newdf[newdf.index.str.contains('Pichu')]
# newdf = newdf.reset_index()
# newdf

# newdf = df.set_index(['Name','Type 1'] , drop=True )
# newdf
# newdf[(newdf.index.get_level_values('Name').str.contains('Pichu'))]

newdf[(newdf.index.get_level_values('Name').str.contains('Pichu'))
      |(newdf.index.get_level_values('Type 1').str.contains('Grass'))]
# Out:
#                                 #    Type 2   HP  Attack  Defense  Sp. Atk  \
# Name                  Type 1
# Bulbasaur             Grass     1    Poison   45      49       49       65
# Ivysaur               Grass     2    Poison   60      62       63       80
# Venusaur              Grass     3    Poison   80      82       83      100
# VenusaurMega Venusaur Grass     3    Poison   80     100      123      122
# Oddish                Grass    43    Poison   45      50       55       75
# ...                           ...       ...  ...     ...      ...      ...
# Chespin               Grass   650       NaN   56      61       65       48
# Quilladin             Grass   651       NaN   61      78       95       56
# Chesnaught            Grass   652  Fighting   88     107      122       74
# Skiddo                Grass   672       NaN   66      65       48       62
# Gogoat                Grass   673       NaN  123     100       62       97
#
# ...

# %% [markdown]
# ## Aggregate Statistics (Groupby)

# %%
# df = pd.read_csv('pokemon_data.csv')
# df

# df.groupby(['Type 1']).count()
# df.groupby(['Type 1']).mean()
# df.groupby(['Type 1']).mean()[['HP','Attack','Defense']]
# df.groupby(['Type 1']).mean()[['HP','Attack','Defense']].sort_values('Defense',ascending=False)
# df.groupby(['Type 1']).agg({'HP':'mean','Attack':'max','Defense':'min'}).sort_values('Defense',ascending=False)
# new syntax
# df.groupby('Type 1').agg(
#     min_HP=pd.NamedAgg(column='HP', aggfunc='min'),
#     max_Attack=pd.NamedAgg(column='Attack', aggfunc='max'),
#     average_Defense=pd.NamedAgg(column='Defense', aggfunc='mean'),
# )

df['c'] = 1
# df.groupby(['Type 1']).count()['c']
# df.groupby(['Type 1', 'Type 2']).count()['c']
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: c, Length: 136, dtype: int64

# %%
# newdf = df[['Name','Type 1','HP']]
# res = newdf.groupby(['Type 1']).agg(list)
# res = df.groupby(['Type 1']).agg(list)['Name'] # the output is a series
# res['Bug']
res = df.groupby(['Type 1']).agg(list)['Name'].to_dict()
res

# res.tail(5)
# Out:
# {'Bug': ['Caterpie',
#   'Metapod',
#   'Butterfree',
#   'Weedle',
#   'Kakuna',
#   'Beedrill',
#   'BeedrillMega Beedrill',
#   'Paras',
#   'Parasect',
#   'Venonat',
#   'Venomoth',
#   'Scyther',
#   'Pinsir',
#   'PinsirMega Pinsir',
#   'Ledyba',
#   'Ledian',
#   'Spinarak',
#   'Ariados',
#   'Yanma',
#   'Pineco',
#   'Forretress',
#   'Scizor',
#   'ScizorMega Scizor',
#   'Shuckle',
#   'Heracross',
#   'HeracrossMega Heracross',
#   'Wurmple',
#   'Silcoon',
#   'Beautifly',
#   'Cascoon',
#   'Dustox',
#   'Surskit',
#   'Masquerain',
#   'Nincada',
#   'Ninjask',
#   'Shedinja',
#   'Volbeat',
#   'Illumise',
#   'Kricketot',
#   'Kricketune',
#   'Burmy',
#   'WormadamPlant Cloak',
#   'WormadamSandy Cloak',
#   'WormadamTrash Cloak',
#   'Mothim',
#   'Combee',
#   'Vespiquen',
#   'Yanmega',
#   'Sewaddle',
#   'Swadloon',
#   'Leavanny',
#   'Venipede',
#   'Whirlipede',
#   'Scolipede',
#   'Dwebble',
#   'Crustle',
#   'Karrablast',
#   'Escavalier',
# ...

# %% [markdown]
# ## Working with large amounts of data

# %%
# for df in pd.read_csv('modified.csv', chunksize=5): #it returns an iterator for the lines of the file
#     print("CHUNK")
#     print(df)



new_df = pd.DataFrame(columns=df.columns)
# new_df

for df in pd.read_csv('pokemon_data.csv', chunksize=50):
    results = df.groupby(['Type 1'] , as_index=False).count()
    new_df = pd.concat([new_df, results] , sort=False , axis=1) #to concat horizontally use axis = 1

new_df['Attack']
# print(new_df[['Type 1']].to_dict())

# new_df.groupby('Type 1').sum()
# df=pd.read_csv('pokemon_data.csv')
# df.groupby('Type 1').count()
# Out:
#     Attack  Attack  Attack  Attack  Attack  Attack  Attack  ...  Attack  \
# 0      NaN     7.0     4.0     3.0     4.0     8.0     5.0  ...     7.0
# 1      NaN     2.0     2.0     4.0     3.0     6.0     2.0  ...     1.0
# 2      NaN     2.0     5.0     2.0     6.0     2.0     2.0  ...     4.0
# 3      NaN     7.0     4.0     2.0     3.0     2.0     2.0  ...     2.0
# 4      NaN     6.0     1.0     3.0     4.0     1.0     7.0  ...     3.0
# 5      NaN     2.0     4.0     3.0     4.0     5.0     7.0  ...     4.0
# 6      NaN    10.0     2.0     4.0     1.0     1.0     2.0  ...     4.0
# 7      NaN    10.0     5.0     1.0     6.0     3.0     1.0  ...     1.0
# 8      NaN     4.0     2.0     8.0     1.0     5.0     8.0  ...     9.0
# 9      NaN     NaN     4.0     2.0     6.0     3.0     2.0  ...     2.0
# 10     NaN     NaN     3.0     3.0     5.0     1.0     4.0  ...     2.0
# 11     NaN     NaN    14.0     2.0     7.0     3.0     8.0  ...     5.0
# ...

# %%
#split df into to dfs
cols=df.columns.to_list()
# left_df = df[cols[0:2]]
# left_df
# right_df = df[cols[1:3]+cols[3:]]
# right_df

# #inner join merge
# merged_inner = pd.merge(left=left_df,right=right_df, left_on='Name', right_on='Name')
# merged_inner

# left/right join
# left_df = pd.concat([left_df,pd.DataFrame(columns=list(left_df.columns),data=np.array(['','Div_left']).reshape(1,2))])
# left_df.reset_index(drop=True,inplace=True)
# left_df

# right_df = pd.concat([right_df,pd.DataFrame(columns=list(right_df.columns),data=np.array(['Div_right','','','','','','','','','','']).reshape(1,11))])
# right_df.reset_index(drop=True,inplace=True)
# right_df

# merged_left = pd.merge(left=left_df,right=right_df, left_on='Name', right_on='Name', how='right')
# merged_left

# # outer join
merged_outer = pd.merge(left=left_df,right=right_df, left_on='Name', right_on='Name', how='outer')
merged_outer

# pd.isnull(merged_outer.iloc[800]['Type 1'])
# Out:
#       #                   Name   Type 1 Type 2   HP Attack Defense Sp. Atk  \
# 0   681   AegislashBlade Forme    Steel  Ghost   60    150      50     150
# 1   681  AegislashShield Forme    Steel  Ghost   60     50     150      50
# 2   682               Spritzee    Fairy    NaN   78     52      60      63
# 3   683             Aromatisse    Fairy    NaN  101     72      72      99
# 4   684                Swirlix    Fairy    NaN   62     48      66      59
# ..  ...                    ...      ...    ...  ...    ...     ...     ...
# 47  720    HoopaHoopa Confined  Psychic  Ghost   80    110      60     150
# 48  720     HoopaHoopa Unbound  Psychic   Dark   80    160      60     170
# 49  721              Volcanion     Fire  Water   80    110     120     130
# 50                    Div_left      NaN    NaN  NaN    NaN     NaN     NaN
# 51  NaN              Div_right
#
#    Sp. Def Speed Generation Legendary
# 0       50    60          6     False
# ...

# %% [markdown]
# ## Display setting

# %%
display_settings = {
    'max_rows': 20,
    'precision': 2,
    'show_dimensions': True,
    'max_columns': 15
}

for op, value in display_settings.items():
    pd.set_option("display.{}".format(op), value)

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False    318
# ...
